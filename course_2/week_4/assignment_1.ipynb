# %%
import pandas as pd
from sklearn import linear_model
import numpy as np
import matplotlib.pyplot as plt

dtype_dict = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':float, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int}

sales = pd.read_csv('kc_house_data.csv', dtype=dtype_dict)
sales = sales.sort_values(['sqft_living','price'])
sales
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 19452  3980300371  20140926T000000   142000.0       0.0       0.00
# 15381  2856101479  20140701T000000   276000.0       1.0       0.75
# 860    1723049033  20140620T000000   245000.0       1.0       0.75
# 18379  1222029077  20141029T000000   265000.0       0.0       0.75
# 4868   6896300380  20141002T000000   228000.0       0.0       1.00
# ...           ...              ...        ...       ...        ...
# 8092   1924059029  20140617T000000  4668000.0       5.0       6.75
# 9254   9208900037  20140919T000000  6885000.0       6.0       7.75
# 3914   9808700762  20140611T000000  7062500.0       5.0       4.50
# 7252   6762700020  20141013T000000  7700000.0       6.0       8.00
# 12777  1225069038  20140505T000000  2280000.0       7.0       8.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 19452        290.0     20875     1.0           0     0  ...      1
# ...

# %%
def polynomial_sframe(feature, degree):
    # assume that degree >= 1
    # initialize the SFrame:
    poly_frame = pd.DataFrame()
    # and set poly_sframe['power_1'] equal to the passed feature
    poly_frame['power_1']=feature
    # first check if degree > 1
    if degree > 1:
        # then loop over the remaining degrees
        # range usually starts at 0 and stops at the endpoint-1. We want it to start at 2 and stop at degree
        for power in range(2, degree+1): 
            # first we'll give the column a name:
            name = 'power_' + str(power)
            # then assign poly_sframe[name] to the appropriate power of feature
            poly_frame[name]=np.power(feature,power)
#             print(power,(feature)**power)

    return poly_frame

# %%
l2_small_penalty = 1.5e-5
print("{0:.11f}".format(l2_small_penalty))
poly15_data = polynomial_sframe(sales['sqft_living'], 15) # use equivalent of `polynomial_sframe`
model = linear_model.Ridge(alpha=l2_small_penalty, normalize=True)
model.fit(poly15_data, sales['price'])
print(model.coef_)
# Out:
# 0.00001500000
# [ 1.24873306e+02 -4.77376011e-02  3.01446238e-05 -2.44419942e-09
#  -1.94153675e-13  8.54085686e-18  1.51142121e-21  8.27979094e-26
#   6.52603100e-31 -3.27895017e-34 -3.87962315e-38 -2.72437650e-42
#  -1.07790800e-46  3.78242694e-51  1.39790296e-54]

# %%
set_1 = pd.read_csv('wk3_kc_house_set_1_data.csv', dtype=dtype_dict)
set_2 = pd.read_csv('wk3_kc_house_set_2_data.csv', dtype=dtype_dict)
set_3 = pd.read_csv('wk3_kc_house_set_3_data.csv', dtype=dtype_dict)
set_4 = pd.read_csv('wk3_kc_house_set_4_data.csv', dtype=dtype_dict)

# %%
l2_small_penalty=1e-9
# print(float(l2_small_penalty))
print("{0:.11f}".format(l2_small_penalty))
# Out:
# 0.00000000100

# %%
poly15_data1 = polynomial_sframe(set_1['sqft_living'], 15) # use equivalent of `polynomial_sframe`
model = linear_model.Ridge(alpha=l2_small_penalty, normalize=True)
model.fit(poly15_data1, set_1['price'])
l=map(lambda i:"{0:.20f}".format(i),list(model.coef_))
print(list(l))
poly15_data2 = polynomial_sframe(set_2['sqft_living'], 15) 
model = linear_model.Ridge(alpha=l2_small_penalty, normalize=True)
model.fit(poly15_data2, set_2['price'])
l=map(lambda i:"{0:.20f}".format(i),list(model.coef_))
print(list(l))
poly15_data3 = polynomial_sframe(set_3['sqft_living'], 15) 
model = linear_model.Ridge(alpha=l2_small_penalty, normalize=True)
model.fit(poly15_data3, set_3['price'])
l=map(lambda i:"{0:.20f}".format(i),list(model.coef_))
print(list(l))
poly15_data4= polynomial_sframe(set_4['sqft_living'], 15) 
model = linear_model.Ridge(alpha=l2_small_penalty, normalize=True)
model.fit(poly15_data4, set_4['price'])
l=map(lambda i:"{0:.20f}".format(i),list(model.coef_))
print(list(l))
# Out:
# ['-15.21071783062537896569', '0.04322619438532191577', '0.00000761301379227169', '-0.00000000101052500813', '-0.00000000000003598302', '0.00000000000000000280', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '-0.00000000000000000000', '-0.00000000000000000000', '-0.00000000000000000000', '-0.00000000000000000000', '-0.00000000000000000000', '0.00000000000000000000']
# ['288.18511529962120221171', '-0.10066666994219287956', '0.00001969373952387326', '0.00000000273446796367', '-0.00000000000021512695', '-0.00000000000000005519', '-0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '-0.00000000000000000000', '-0.00000000000000000000', '-0.00000000000000000000']
# ...

# %%
# plt.plot(poly15_data1['power_1'],model.predict(set_1['sqft_living'].values[:, np.newaxis]),'.')
#          poly15_data['power_1'], model2.predict(set_2['sqft_living']),'-',
#         poly15_data1['power_1'],model.predict(set_1['sqft_living']),'x',
#          poly15_data1['power_1'],model.predict(set_1['sqft_living']),'o',
#          )
poly15_data
# Out:
#        power_1      power_2       power_3       power_4       power_5  \
# 19452    290.0      84100.0  2.438900e+07  7.072810e+09  2.051115e+12
# 15381    370.0     136900.0  5.065300e+07  1.874161e+10  6.934396e+12
# 860      380.0     144400.0  5.487200e+07  2.085136e+10  7.923517e+12
# 18379    384.0     147456.0  5.662310e+07  2.174327e+10  8.349416e+12
# 4868     390.0     152100.0  5.931900e+07  2.313441e+10  9.022420e+12
# ...        ...          ...           ...           ...           ...
# 8092    9640.0   92929600.0  8.958413e+11  8.635911e+15  8.325018e+19
# 9254    9890.0   97812100.0  9.673617e+11  9.567207e+15  9.461968e+19
# 3914   10040.0  100801600.0  1.012048e+12  1.016096e+16  1.020161e+20
# 7252   12050.0  145202500.0  1.749690e+12  2.108377e+16  2.540594e+20
# 12777  13540.0  183331600.0  2.482310e+12  3.361048e+16  4.550858e+20
#
#             power_6       power_7       power_8       power_9      power_10  \
# ...

# %%
set_1
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 0     8658300340  20140523T000000    80000.0       1.0       0.75
# 1     1352300580  20141114T000000   247000.0       1.0       1.00
# 2     1320069249  20141020T000000   192500.0       1.0       1.00
# 3     1437500015  20140709T000000   150000.0       3.0       0.75
# 4     0859000110  20141002T000000   125000.0       1.0       1.00
# ...          ...              ...        ...       ...        ...
# 5399  8907500070  20150413T000000  5350000.0       5.0       5.00
# 5400  1247600105  20141020T000000  5110800.0       5.0       5.25
# 5401  2303900035  20140611T000000  2888000.0       5.0       6.25
# 5402  6762700020  20141013T000000  7700000.0       6.0       8.00
# 5403  1225069038  20140505T000000  2280000.0       7.0       8.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0           430.0      5050     1.0           0     0  ...      4         430
# ...

# %%
l2_large_penalty=1.23e2
# print(float(l2_small_penalty))
print("{0:.11f}".format(l2_large_penalty))

poly15_data1 = polynomial_sframe(set_1['sqft_living'], 15) # use equivalent of `polynomial_sframe`
model = linear_model.Ridge(alpha=l2_large_penalty, normalize=True)
model.fit(poly15_data1, set_1['price'])
l=map(lambda i:"{0:.20f}".format(i),list(model.coef_))
print(list(l))
poly15_data2 = polynomial_sframe(set_2['sqft_living'], 15) 
model = linear_model.Ridge(alpha=l2_large_penalty, normalize=True)
model.fit(poly15_data2, set_2['price'])
l=map(lambda i:"{0:.20f}".format(i),list(model.coef_))
print(list(l))
poly15_data3 = polynomial_sframe(set_3['sqft_living'], 15) 
model = linear_model.Ridge(alpha=l2_large_penalty, normalize=True)
model.fit(poly15_data3, set_3['price'])
l=map(lambda i:"{0:.20f}".format(i),list(model.coef_))
print(list(l))
poly15_data4= polynomial_sframe(set_4['sqft_living'], 15) 
model = linear_model.Ridge(alpha=l2_large_penalty, normalize=True)
model.fit(poly15_data4, set_4['price'])
l=map(lambda i:"{0:.20f}".format(i),list(model.coef_))
print(list(l))
# Out:
# 123.00000000000
# ['2.32806802957932479359', '0.00035362160794180360', '0.00000003319696917703', '0.00000000000200082477', '0.00000000000000011149', '0.00000000000000000001', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000']
# ['2.09756902777855502862', '0.00039081748325338903', '0.00000006671899443540', '0.00000000000890002997', '0.00000000000000097264', '0.00000000000000000010', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000', '0.00000000000000000000']
# ...

# %%
train_valid_shuffled = pd.read_csv('wk3_kc_house_train_valid_shuffled.csv', dtype=dtype_dict)
test = pd.read_csv('wk3_kc_house_test_data.csv', dtype=dtype_dict)

# %%
def get_rss(predictions,output):
    RSS=predictions-output
    RSS=RSS*RSS
    RSS=RSS.sum()
    return RSS

n = len(train_valid_shuffled)
k = 10 # 10-fold cross-validation


for i in range(k):
    start = (n*i)//k
    end = (n*(i+1))//k-1
    print(i, (start, end))
    val_set=train_valid_shuffled[start:end+1]
    train_set=train_valid_shuffled[0:start].append(train_valid_shuffled[end+1:n])
#     poly15_data= polynomial_sframe(train_set['sqft_living'], 15) 
    model = linear_model.Ridge(alpha=l2_penalty, normalize=True)
    model.fit(train_set, train_set['price'])
#     poly15_data_val= polynomial_sframe(val_set['sqft_living'], 15) 
#     poly15_data_val['price'] = val_set['price']
    predictions=model.predict(val_set.iloc[:,:15].values)
    error=get_rss(predictions,poly15_data_val["price"])
# Out:
# 0 (0, 1938)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-21c3102ff0cd> in <module>
#      17 #     poly15_data= polynomial_sframe(train_set['sqft_living'], 15)
#      18     model = linear_model.Ridge(alpha=l2_penalty, normalize=True)
# ---> 19     model.fit(train_set, train_set['price'])
#      20 #     poly15_data_val= polynomial_sframe(val_set['sqft_living'], 15)
#      21 #     poly15_data_val['price'] = val_set['price']
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py in fit(self, X, y, sample_weight)
#     764         self : returns an instance of self.
#     765         """
# --> 766         return super().fit(X, y, sample_weight=sample_weight)
#     767
#     768
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py in fit(self, X, y, sample_weight)
# ...

# %%
def k_fold_cross_validation(k_fold_cross_validation, l2_penalty, data):
    error=0
    for i in range(k):
        start = (n*i)//k
        end = (n*(i+1))//k-1
#         print(i, (start, end))
        val_set=data[start:end+1]
        train_set=data[0:start].append(data[end+1:n])
        poly15_data= polynomial_sframe(train_set['sqft_living'], 15) 
        model = linear_model.Ridge(alpha=l2_penalty, normalize=True)
        model.fit(poly15_data, train_set['price'])
        poly15_data_val= polynomial_sframe(val_set['sqft_living'], 15) 
        poly15_data_val['price'] = val_set['price']
        predictions=model.predict(poly15_data_val.loc[:,:'power_15'].values)
        error+=get_rss(predictions,poly15_data_val["price"])
    return error/k 

l2_penalty=np.logspace(3, 9, num=13)
l=[]
for i in l2_penalty:
#     print(i)
    l.append(k_fold_cross_validation(10,i,train_valid_shuffled))
#     print("\n")
print(l)
print(min(l))
# Out:
# 1000.0
# 3162.2776601683795
# 10000.0
# 31622.776601683792
# 100000.0
# 316227.7660168379
# 1000000.0
# 3162277.6601683795
# 10000000.0
# 31622776.60168379
# 100000000.0
# 316227766.01683795
# 1000000000.0
# [264977361036975.94, 265692935858318.25, 265924368957215.66, 265998081509342.66, 266021444553980.5, 266028837918724.5, 266031176438467.9, 266031915996607.4, 266032149870752.5, 266032223828783.66, 266032247216419.84, 266032254612245.16, 266032256951011.06]
# 264977361036975.94

# %%
poly15_data
# Out:
#        power_1     power_2       power_3       power_4       power_5  \
# 0       2800.0   7840000.0  2.195200e+10  6.146560e+13  1.721037e+17
# 1       2490.0   6200100.0  1.543825e+10  3.844124e+13  9.571869e+16
# 2       2340.0   5475600.0  1.281290e+10  2.998220e+13  7.015834e+16
# 3       1320.0   1742400.0  2.299968e+09  3.035958e+12  4.007464e+15
# 4       1904.0   3625216.0  6.902411e+09  1.314219e+13  2.502273e+16
# ...        ...         ...           ...           ...           ...
# 19391   2480.0   6150400.0  1.525299e+10  3.782742e+13  9.381200e+16
# 19392   1670.0   2788900.0  4.657463e+09  7.777963e+12  1.298920e+16
# 19393   2403.0   5774409.0  1.387590e+10  3.334380e+13  8.012515e+16
# 19394   3780.0  14288400.0  5.401015e+10  2.041584e+14  7.717187e+17
# 19395   2400.0   5760000.0  1.382400e+10  3.317760e+13  7.962624e+16
#
#             power_6       power_7       power_8       power_9      power_10  \
# ...

# %%
np.logspace(3, 9, num=13)
# Out:
# array([1.00000000e+03, 3.16227766e+03, 1.00000000e+04, 3.16227766e+04,
#        1.00000000e+05, 3.16227766e+05, 1.00000000e+06, 3.16227766e+06,
#        1.00000000e+07, 3.16227766e+07, 1.00000000e+08, 3.16227766e+08,
#        1.00000000e+09])

# %%
train=pd.read_csv("wk3_kc_house_train_data.csv")
test=pd.read_csv("wk3_kc_house_test_data.csv")

# %%
l2_penalty=1000
poly15_data= polynomial_sframe(train['sqft_living'], 15) 
model = linear_model.Ridge(alpha=l2_penalty, normalize=True)
model.fit(poly15_data, train['price'])
poly15_data_test= polynomial_sframe(test['sqft_living'], 15) 
poly15_data_test['price'] = test['price']
predictions=model.predict(poly15_data_test.iloc[:,:15].values)
error=get_rss(predictions,poly15_data_test["price"])

# %%
print(error)
# Out:
# 283706518061282.5

# %%
poly15_data_test.loc[:,:'power_15'].values.shape
# Out:
# (2217, 15)

# %%
poly15_data_test.iloc[:,:15].values.shape
# Out:
# (2217, 15)

# %%
print("{0:.20f}".format(8e13))
# Out:
# 80000000000000.00000000000000000000

# %%
from decimal import Decimal

'%.2E' % Decimal('283706518061282.5')
# Out:
# '2.84E+14'

# %%
def k_fold_cross_validation(k, l2_penalty, data):
    error=0
    for i in range(k):
        start = (n*i)//k
        end = (n*(i+1))//k-1
#         print(i, (start, end))
        val_set=data[start:end+1]
        train_set=data[0:start].append(data[end+1:n])
#         poly15_data= polynomial_sframe(train_set['sqft_living'], 15) 
        model = linear_model.Ridge(alpha=l2_penalty, normalize=True)
        model.fit(train_set.iloc[:,:15].values, train_set['price'])
#         poly15_data_val= polynomial_sframe(val_set['sqft_living'], 15) 
#         poly15_data_val['price'] = val_set['price']
        predictions=model.predict(val_set.iloc[:,:15].values)
        error+=get_rss(predictions,val_set["price"])
    return error/k 

l2_penalty=np.logspace(3, 9, num=13)
l=[]
for i in l2_penalty:
    print(i)
    poly_data = polynomial_sframe(train_valid_shuffled['sqft_living'], 15)
    poly_data["price"]=train_valid_shuffled["price"]
    l.append(k_fold_cross_validation(10,i,poly_data))
    print("\n")
print(l)
print(min(l))
# Out:
# 1000.0
#
#
# 3162.2776601683795
#
#
# 10000.0
#
#
# 31622.776601683792
#
#
# 100000.0
#
#
# 316227.7660168379
#
#
# 1000000.0
#
#
# 3162277.6601683795
#
#
# 10000000.0
#
#
# 31622776.60168379
#
#
# 100000000.0
#
#
# 316227766.01683795
#
#
# 1000000000.0
#
#
# [264977361036975.94, 265692935858318.25, 265924368957215.66, 265998081509342.66, 266021444553980.5, 266028837918724.5, 266031176438467.9, 266031915996607.4, 266032149870752.5, 266032223828783.66, 266032247216419.84, 266032254612245.16, 266032256951011.06]
# 264977361036975.94

# %%
poly_data = polynomial_sframe(train_valid_shuffled['sqft_living'], 15)
poly_data["price"]=train_valid_shuffled["price"]
poly_data.iloc[:,:16]
# Out:
#        power_1     power_2       power_3       power_4       power_5  \
# 0       2800.0   7840000.0  2.195200e+10  6.146560e+13  1.721037e+17
# 1       2490.0   6200100.0  1.543825e+10  3.844124e+13  9.571869e+16
# 2       2340.0   5475600.0  1.281290e+10  2.998220e+13  7.015834e+16
# 3       1320.0   1742400.0  2.299968e+09  3.035958e+12  4.007464e+15
# 4       1904.0   3625216.0  6.902411e+09  1.314219e+13  2.502273e+16
# ...        ...         ...           ...           ...           ...
# 19391   2480.0   6150400.0  1.525299e+10  3.782742e+13  9.381200e+16
# 19392   1670.0   2788900.0  4.657463e+09  7.777963e+12  1.298920e+16
# 19393   2403.0   5774409.0  1.387590e+10  3.334380e+13  8.012515e+16
# 19394   3780.0  14288400.0  5.401015e+10  2.041584e+14  7.717187e+17
# 19395   2400.0   5760000.0  1.382400e+10  3.317760e+13  7.962624e+16
#
#             power_6       power_7       power_8       power_9      power_10  \
# ...
