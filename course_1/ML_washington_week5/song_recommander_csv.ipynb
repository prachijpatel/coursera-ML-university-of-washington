# %%
import pandas as pd
import numpy as np
df=pd.read_csv("song_data.csv")
df
# Out:
#                                           user_id             song_id  \
# 0        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995
# 1        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 2        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0
# 3        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D
# 4        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273
# ...                                           ...                 ...
# 1116604  276e43ad698705e5011e5091f367d951b21246f5  SOWTYVO12AB0180BDA
# 1116605  276e43ad698705e5011e5091f367d951b21246f5  SOWZHOY12A6701F9FC
# 1116606  276e43ad698705e5011e5091f367d951b21246f5  SOXJOZW12A6701E90E
# 1116607  276e43ad698705e5011e5091f367d951b21246f5  SOXNKNC12A6701F7A8
# 1116608  276e43ad698705e5011e5091f367d951b21246f5  SOYRMVO12A6701D106
#
#          listen_count                                              title  \
# ...

# %%
duplicate=df
duplicate["listen_count"]=1
duplicate
# Out:
#                                           user_id             song_id  \
# 0        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995
# 1        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 2        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0
# 3        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D
# 4        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273
# ...                                           ...                 ...
# 1116604  276e43ad698705e5011e5091f367d951b21246f5  SOWTYVO12AB0180BDA
# 1116605  276e43ad698705e5011e5091f367d951b21246f5  SOWZHOY12A6701F9FC
# 1116606  276e43ad698705e5011e5091f367d951b21246f5  SOXJOZW12A6701E90E
# 1116607  276e43ad698705e5011e5091f367d951b21246f5  SOXNKNC12A6701F7A8
# 1116608  276e43ad698705e5011e5091f367d951b21246f5  SOYRMVO12A6701D106
#
#          listen_count                                              title  \
# ...

# %%
df1=duplicate.groupby("artist").sum()
df1
# Out:
#                       listen_count
# artist
# !!!                             53
# + / - {Plus/Minus}             184
# +44                            124
# 10 Years                       128
# 1001                            43
# ...                            ...
# moe.                            81
# rinôçérôse                      45
# the bird and the bee          1520
# themselves                      44
# tobyMac                        149
#
# [3375 rows x 1 columns]

# %%
df1.index[df1["listen_count"]==df1["listen_count"].max()]
# Out:
# Index(['Coldplay'], dtype='object', name='artist')

# %%
df1.loc["Kanye West"]
# Out:
# listen_count    3775
# Name: Kanye West, dtype: int64

# %%
df1.loc["Foo Fighters"]
# Out:
# listen_count    3429
# Name: Foo Fighters, dtype: int64

# %%
df1.loc["Taylor Swift"]
# Out:
# listen_count    6227
# Name: Taylor Swift, dtype: int64

# %%
df1.loc["Lady GaGa"]
# Out:
# listen_count    4129
# Name: Lady GaGa, dtype: int64

# %%
df2=df.groupby("artist").sum()

# %%
df2.index[df2["listen_count"]==df2["listen_count"].max()]
# Out:
# Index(['Coldplay'], dtype='object', name='artist')

# %%
df2.index[df2["listen_count"]==df2["listen_count"].min()]
# Out:
# Index(['William Tabbert'], dtype='object', name='artist')

# %%
df1.sort_values("listen_count")
# Out:
#                         listen_count
# artist
# William Tabbert                   12
# Elvis Perkins                     20
# Reel Feelings                     22
# harvey summers                    22
# Giannis Aggelakas                 23
# ...                              ...
# The Black Keys                  8141
# Justin Bieber                   8796
# Kings Of Leon                   9908
# Florence + The Machine         10082
# Coldplay                       13945
#
# [3375 rows x 1 columns]

# %%
df2.sort_values("listen_count")
# Out:
#                         listen_count
# artist
# William Tabbert                   12
# Elvis Perkins                     20
# Reel Feelings                     22
# harvey summers                    22
# Giannis Aggelakas                 23
# ...                              ...
# The Black Keys                  8141
# Justin Bieber                   8796
# Kings Of Leon                   9908
# Florence + The Machine         10082
# Coldplay                       13945
#
# [3375 rows x 1 columns]
